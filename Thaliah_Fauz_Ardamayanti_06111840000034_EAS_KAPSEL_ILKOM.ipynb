# %% [markdown]
# # EAS KAPSEL ILKOM 2021
# ## DEPARTEMEN MATEMATIKA ITS
# ### Thaliah Fauz Ardamayanti
# ### NRP. 06111840000034

# %% [markdown]
# 1.   Akan dilakukan analisis terhadap **data.xlsx** dengan menggunakan Phyton dan **Library Scikit Learn**.
# 2.   Akan digunakan beberapa metode regresi untuk mencari model terbaik untuk _y_.
# 3.  Metode Regresi yang digunakan antara lain:
#     * _Linear Regression_
#     * _Ridge Regression_
#     * _Lasso Regression_
#     * _Bayesian Ridge Regression_
#     * _Elasctic Net Regression_
#     * _Orthogonal Matching Pursuit_
#     * _Generalized Linear Model (GLM)_ atau _Tweedie Regressor_
#     * _Stochastic Gradient Descent_
#     * _Polynomial Regression_ menggunakan _Pipeline_ dan secara manual
#     * _Support Vector Machine (SVN) for Regression_
#     * _Nearest Neighbors_
#     * _Desicion Tree Regression_
#     * _Multi-layer Perceptron_
# 4. Analisis perbandingan beberapa model tersebut didasarkan pada hasil _Mean Absolute Percentage Error_ (MAPE), _Root Mean Squared Error_ (RMSE), dan _Coefficient of Determination_ (R2) yang dihasilkan oleh masing-masing metode.

# %% [markdown]
# ## Import Library

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in /usr/local/lib/python3.7/dist-packages (0.24.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)

# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, r2_score

# Normalization (Min Max Scaler)
from sklearn.preprocessing import MinMaxScaler

# Linear Regression
from sklearn.linear_model import LinearRegression

# Ridge Regression
from sklearn.linear_model import Ridge

# Lasso Regression
from sklearn.linear_model import Lasso

# Bayesian Ridge Regression
from sklearn.linear_model import BayesianRidge

# Elastic Net Regression
from sklearn.linear_model import ElasticNet

# Orthogonal Matching Pursuit
from sklearn.linear_model import OrthogonalMatchingPursuit

# Generalized Linear Model (GLM) / Tweedie Regressor
from sklearn.linear_model import TweedieRegressor

# Stochastic Gradient Descent
from sklearn.linear_model import SGDRegressor

# Polynomial Regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

# Support Vector Machines (SVM) for Regression
from sklearn.svm import SVR

# Nearest Neighbors
from sklearn.neighbors import KNeighborsRegressor

# Decision Tree Regression
from sklearn.tree import DecisionTreeRegressor

# Multi-layer Perceptron
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# ## Input X

# %%
x = pd.read_excel('/data.xlsx', sheet_name='Sheet1', usecols = "A:J")
x = pd.DataFrame(x)
x
# Out:
#       x1  x2  x3   x4  x5  x6  x7  x8  x9  x10
# 0     63  95  61   59  83  62  60  64  56   90
# 1    100  85  71   85  64  94  97  65  98   66
# 2     81  50  80  100  67  78  62  79  54   73
# 3     92  86  50   87  52  98  99  75  83   95
# 4     60  55  70   77  75  77  97  89  91   52
# ..   ...  ..  ..  ...  ..  ..  ..  ..  ..  ...
# 995   66  63  73   86  69  95  80  72  78   65
# 996   96  59  98   91  99  94  63  91  59   53
# 997   87  77  58   54  97  58  76  52  55   54
# 998   70  59  70   67  84  90  95  78  60   71
# 999   89  57  81   96  73  62  54  51  91   92
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## Output Y

# %%
y = pd.read_excel('/data.xlsx', sheet_name='Sheet1', usecols = "K")
y = pd.DataFrame(y)
y
# Out:
#           y
# 0     18178
# 1    118804
# 2     51562
# 3     90026
# 4     23908
# ..      ...
# 995   31198
# 996   92549
# 997   60795
# 998   32503
# 999   68889
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## Normalisasi Input (Min Max Scaler)

# %%
scaler = MinMaxScaler()
columns = x.columns
x = scaler.fit_transform(x)
x = pd.DataFrame(x)
x.columns = columns
x
# Out:
#        x1    x2    x3    x4    x5    x6    x7    x8    x9   x10
# 0    0.26  0.90  0.22  0.18  0.66  0.24  0.20  0.28  0.12  0.80
# 1    1.00  0.70  0.42  0.70  0.28  0.88  0.94  0.30  0.96  0.32
# 2    0.62  0.00  0.60  1.00  0.34  0.56  0.24  0.58  0.08  0.46
# 3    0.84  0.72  0.00  0.74  0.04  0.96  0.98  0.50  0.66  0.90
# 4    0.20  0.10  0.40  0.54  0.50  0.54  0.94  0.78  0.82  0.04
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 995  0.32  0.26  0.46  0.72  0.38  0.90  0.60  0.44  0.56  0.30
# 996  0.92  0.18  0.96  0.82  0.98  0.88  0.26  0.82  0.18  0.06
# 997  0.74  0.54  0.16  0.08  0.94  0.16  0.52  0.04  0.10  0.08
# 998  0.40  0.18  0.40  0.34  0.68  0.80  0.90  0.56  0.20  0.42
# 999  0.78  0.14  0.62  0.92  0.46  0.24  0.08  0.02  0.82  0.84
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## Normalisasi Output (Min Max Scaler)

# %%
scaler = MinMaxScaler()
columns = y.columns
y = scaler.fit_transform(y)
y = pd.DataFrame(y)
y.columns = columns
y
# Out:
#             y
# 0    0.096452
# 1    0.991805
# 2    0.393497
# 3    0.735743
# 4    0.147437
# ..        ...
# 995  0.212302
# 996  0.758193
# 997  0.475651
# 998  0.223914
# 999  0.547670
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## Split Data

# %%
x_train = x.loc[0:799]

x_valid = x.loc[800:999]
x_valid.index = range(200)

y_train = y[0:800]

y_valid = y[800:1000]
y_valid.index = range(200)

print(x_train)
print(x_valid)
print(y_train)
print(y_valid)
# Out:
#        x1    x2    x3    x4    x5    x6    x7    x8    x9   x10
# 0    0.26  0.90  0.22  0.18  0.66  0.24  0.20  0.28  0.12  0.80
# 1    1.00  0.70  0.42  0.70  0.28  0.88  0.94  0.30  0.96  0.32
# 2    0.62  0.00  0.60  1.00  0.34  0.56  0.24  0.58  0.08  0.46
# 3    0.84  0.72  0.00  0.74  0.04  0.96  0.98  0.50  0.66  0.90
# 4    0.20  0.10  0.40  0.54  0.50  0.54  0.94  0.78  0.82  0.04
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 795  0.92  0.80  0.32  0.18  0.00  0.78  0.26  0.42  0.26  0.62
# 796  0.26  0.28  0.38  0.12  0.02  0.78  0.20  0.84  0.98  0.10
# 797  0.58  0.26  0.72  0.52  0.52  0.68  0.98  0.10  0.00  0.94
# 798  0.88  0.06  0.76  0.08  0.68  0.52  0.24  0.52  0.00  0.38
# 799  0.96  0.90  0.44  0.06  0.48  0.18  0.70  0.32  0.86  0.48
#
# [800 rows x 10 columns]
#        x1    x2    x3    x4    x5    x6    x7    x8    x9   x10
# 0    0.00  0.92  0.56  0.34  0.90  0.64  0.98  0.50  0.28  0.00
# 1    0.76  0.50  0.10  0.36  0.00  0.80  0.90  0.44  0.18  0.26
# 2    0.60  0.60  0.18  0.20  0.40  0.90  0.98  0.16  0.96  0.88
# 3    0.06  0.64  0.44  0.76  0.64  0.02  0.74  0.12  0.14  0.68
# 4    0.30  0.42  0.60  0.40  0.58  0.96  0.36  0.58  0.92  0.92
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 195  0.32  0.26  0.46  0.72  0.38  0.90  0.60  0.44  0.56  0.30
# 196  0.92  0.18  0.96  0.82  0.98  0.88  0.26  0.82  0.18  0.06
# 197  0.74  0.54  0.16  0.08  0.94  0.16  0.52  0.04  0.10  0.08
# 198  0.40  0.18  0.40  0.34  0.68  0.80  0.90  0.56  0.20  0.42
# 199  0.78  0.14  0.62  0.92  0.46  0.24  0.08  0.02  0.82  0.84
#
# [200 rows x 10 columns]
#             y
# 0    0.096452
# 1    0.991805
# 2    0.393497
# 3    0.735743
# 4    0.147437
# ..        ...
# 795  0.792716
# 796  0.133405
# 797  0.385222
# 798  0.660299
# 799  0.817426
#
# [800 rows x 1 columns]
#             y
# 0    0.070088
# 1    0.595603
# 2    0.409256
# 3    0.100474
# 4    0.135808
# ..        ...
# 195  0.212302
# 196  0.758193
# 197  0.475651
# 198  0.223914
# 199  0.547670
#
# [200 rows x 1 columns]

# %% [markdown]
# ## Linear Regression

# %%
model = LinearRegression()
model.fit(x_train, y_train)

y_valid_pred = model.predict(x_valid)

print('Mean Absolute Percentage Error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root Mean Squared Error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of Determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

print(model.intercept_)
print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Linear Regression')
plt.legend()
plt.show()
# Out:
# Mean Absolute Percentage Error (MAPE): 0.41
# Root Mean Squared Error (RMSE): 0.06
# Coefficient of Determination (R2): 0.94
# [-0.13762301]
# [[ 8.36923371e-01  2.28497212e-02 -5.70740472e-03  7.32186561e-02
#   -5.47019458e-02  2.43279575e-02  6.44499586e-02  2.14272434e-03
#   -7.57483868e-04  1.72163950e-02]]

# %% [markdown]
# ## Ridge Regression

# %%
model = Ridge(alpha=15)
model.fit(x_train, y_train)

y_valid_pred = model.predict(x_valid)

print('Mean Absolute Percentage Error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root Mean Squared Error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of Determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

print(model.intercept_)
print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Ridge Regression')
plt.legend()
plt.show()
# Out:
# Mean Absolute Percentage Error (MAPE): 0.25
# Root Mean Squared Error (RMSE): 0.08
# Coefficient of Determination (R2): 0.91
# [-0.05516163]
# [[ 6.85857433e-01  2.46667860e-02  2.48996104e-03  5.71525328e-02
#   -4.43150426e-02  2.11421481e-02  4.88604289e-02 -6.48242214e-04
#    2.54872910e-03  2.04318196e-02]]

# %% [markdown]
# ## Lasso Regression

# %%
model = Lasso(alpha=0.009)
model.fit(x_train, y_train)

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

print(model.intercept_)
print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Lasso Regression')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.29
# Root mean squared error (RMSE): 0.07
# Coefficient of determination (R2): 0.92
# [-0.01164602]
# [ 0.72989989  0.          0.          0.         -0.          0.
#   0.          0.          0.          0.        ]

# %% [markdown]
# ## Bayesian Ridge Regression

# %%
model = BayesianRidge()
model.fit(x_train, y_train.values.ravel())

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

print(model.intercept_)
print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Bayesian Ridge Regression')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.40
# Root mean squared error (RMSE): 0.06
# Coefficient of determination (R2): 0.94
# -0.13729957042879326
# [ 8.36318574e-01  2.28629097e-02 -5.66814678e-03  7.31515937e-02
#  -5.46602573e-02  2.43162668e-02  6.43836489e-02  2.13004908e-03
#  -7.41588882e-04  1.72352122e-02]

# %% [markdown]
# ## Elastic Net Regression

# %%
model =  ElasticNet(alpha=0.005, l1_ratio=1)
model.fit(x_train, y_train)

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))
print('Weights of the model:')
#print(model.coef_)
for i in model.coef_:
    print('\t%.5f' % i)
print('Intercept of the model: %.5f' % model.intercept_)
print()

plt.figure(figsize=(15, 6))
plt.plot(y_valid, label ='Actual')
plt.plot(y_valid_pred, label ='Prediction')
plt.title('Elastic Net Regression Regression')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.32
# Root mean squared error (RMSE): 0.07
# Coefficient of determination (R2): 0.93
# Weights of the model:
# 	0.77689
# 	0.00000
# 	-0.00000
# 	0.01342
# 	-0.00000
# 	0.00000
# 	0.00756
# 	0.00000
# 	0.00000
# 	0.00000
# Intercept of the model: -0.04606

# %% [markdown]
# ## Orthogonal Matching Pursuit

# %%
model = OrthogonalMatchingPursuit(n_nonzero_coefs=8)
model.fit(x_train, y_train)

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

print(model.intercept_)
print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Orthogonal Matching Pursuit')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.41
# Root mean squared error (RMSE): 0.06
# Coefficient of determination (R2): 0.94
# [-0.13684395]
# [ 0.83684589  0.02288201 -0.00576319  0.07334015 -0.05481003  0.02441163
#   0.06435622  0.          0.          0.01710768]

# %% [markdown]
# ## Generalized Linear Model (GLM) / Tweedie Regressor

# %%
model = TweedieRegressor(power=1, alpha=0.00034)
model.fit(x_train, y_train.values.ravel())

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

print(model.intercept_)
print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Generalized Linear Model (GLM) / Tweedie Regressor')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.18
# Root mean squared error (RMSE): 0.03
# Coefficient of determination (R2): 0.99
# -2.79935071431497
# [ 2.55701565  0.06168951  0.01669666  0.16943508 -0.09486132  0.07108643
#   0.18121113  0.00370666  0.01166299 -0.00611006]

# %% [markdown]
# ## Stochastic Gradient Descent

# %%
model = SGDRegressor()
model.fit(x_train, y_train.values.ravel())

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

print(model.intercept_)
print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Stochastic Gradient Descent')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.44
# Root mean squared error (RMSE): 0.11
# Coefficient of determination (R2): 0.83
# [0.03432092]
# [ 0.55318028  0.02548521  0.00853067  0.03534532 -0.04032875  0.01285623
#   0.02962051 -0.00679261  0.00334758  0.02407009]

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# ### Dengan Pipeline

# %%
model = Pipeline([('poly', PolynomialFeatures(degree=3, include_bias=False)),
                  ('linear', LinearRegression())])
model.fit(x_train, y_train)

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

#print(model.intercept_)
#print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Polynomial Regression Dengan Pipelin')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.06
# Root mean squared error (RMSE): 0.01
# Coefficient of determination (R2): 1.00

# %% [markdown]
# ### Tanpa Pipeline (Manual)

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)
x_train_poly = poly.fit_transform(x_train)
x_valid_poly = poly.transform(x_valid)

x_train_poly = pd.DataFrame(x_train_poly)
x_valid_poly = pd.DataFrame(x_valid_poly)

x_train_poly.columns = poly.get_feature_names(x_train.columns)
x_valid_poly.columns = poly.get_feature_names(x_train.columns)

#print(x_train)
#print(x_train_poly)

model = LinearRegression()
model.fit(x_train_poly, y_train)

y_valid_pred = model.predict(x_valid_poly)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

#print(model.intercept_)
#print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Polynomial Regression Tanpa Pipeline (Manual)')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.07
# Root mean squared error (RMSE): 0.01
# Coefficient of determination (R2): 1.00

# %% [markdown]
# ## Support Vector Machines (SVM) for Regression

# %%
model = SVR(kernel='poly')
model.fit(x_train, y_train.values.ravel())

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

#print(model.intercept_)
#print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Support Vector Machines (SVM) for Regression')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.30
# Root mean squared error (RMSE): 0.05
# Coefficient of determination (R2): 0.96

# %% [markdown]
# ## Nearest Neighbors

# %%
model = KNeighborsRegressor(n_neighbors=5, weights='distance')
model.fit(x_train, y_train)

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

#print(model.intercept_)
#print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Nearest Neighbors')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.44
# Root mean squared error (RMSE): 0.12
# Coefficient of determination (R2): 0.80

# %% [markdown]
# ## Decision Tree Regression

# %%
model = DecisionTreeRegressor(max_depth=9)
model.fit(x_train, y_train)

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

#print(model.intercept_)
#print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Decision Tree Regression')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.13
# Root mean squared error (RMSE): 0.04
# Coefficient of determination (R2): 0.98

# %% [markdown]
# ## Multi-layer Perceptron

# %%
model = MLPRegressor(hidden_layer_sizes=(100), activation='logistic', solver='adam', max_iter=15000)
model.fit(x_train, y_train.values.ravel())

y_valid_pred = model.predict(x_valid)

print('Mean absolute percentage error (MAPE): %.2f' % mean_absolute_percentage_error(y_valid, y_valid_pred))
print('Root mean squared error (RMSE): %.2f' % np.sqrt(mean_squared_error(y_valid, y_valid_pred)))
print('Coefficient of determination (R2): %.2f' % r2_score(y_valid, y_valid_pred))

#print(model.intercept_)
#print(model.coef_)

plt.figure(figsize=(15,6))
plt.plot(y_valid, label='Actual')
plt.plot(y_valid_pred, label='Prediction')
plt.title('Multi-layer Perceptron')
plt.legend()
plt.show()
# Out:
# Mean absolute percentage error (MAPE): 0.31
# Root mean squared error (RMSE): 0.07
# Coefficient of determination (R2): 0.93
